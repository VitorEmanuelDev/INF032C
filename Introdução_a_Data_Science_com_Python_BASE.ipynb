# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorEmanuelDev/INF032C/blob/master/Introdu%C3%A7%C3%A3o_a_Data_Science_com_Python_BASE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# ## <font color="#106eb2" size=12>Introdução a Data Science com Python</font>
# ***

# %% [markdown]
# ## <font color="#1D334A" size=8>Aula 01 - Conhecendo os Dados</font>

# %% [markdown]
# Esta primeira aula é dedicada a realizar uma análise inicial de uma amostra de dados dos participantes do ENEM 2019.
#
# É importante conhecer a semântica dos dados descrita no dicionário de dados. A exploração inicial, o conhecimento do negócio, e do dicionário de dados é importante para a formulação de hipóteses.
#
# Os dados foram extraídos de http://inep.gov.br/microdados

# %% [markdown]
# ### Importando bibliotecas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
dados_df = pd.read_csv("/content/drive/MyDrive/INF032/DataSet Enem2019/microdados_sample.csv")
dados = pd.DataFrame(dados_df)
print(dados)
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0       190001004661    2019                  1506138  ...    A     B    B
# 1       190001004674    2019                  1504208  ...    A     A    B
# 2       190001004722    2019                  1501402  ...    A     A    B
# 3       190001004735    2019                  1507300  ...    A     A    B
# 4       190001004776    2019                  1500800  ...    A     A    B
# ...              ...     ...                      ...  ...  ...   ...  ...
# 127375  190006120035    2019                  3142700  ...    A     B    B
# 127376  190006120036    2019                  2902807  ...    A     B    B
# 127377  190006120037    2019                  2927408  ...    A     A    B
# 127378  190006120060    2019                  2930709  ...    A     A    A
# 127379  190006120170    2019                  3106200  ...    B     A    B
#
# [127380 rows x 136 columns]

# %% [markdown]
# ### EXPOSIÇÃO INICIAL

# %% [markdown]
# Os dados serão carregados em um dataframe.
#
# Um dataframe é a estrutura fundamental do Pandas.
#
# É uma estrutura bidimensional homogênea. As linhas representam os indivíduos da minha amostra ou população. As colunas são os
# atributos destes indivíduos
#
# Para explorar os métodos e atributos dos dataframes: https://pandas.pydata.org/pandas-docs/stable/reference/frame.html

# %%
dados.head(10)
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
# 3  190001004735    2019                  1507300  ...    A     A    B
# 4  190001004776    2019                  1500800  ...    A     A    B
# 5  190001004841    2019                  1503606  ...    A     B    B
# 6  190001004856    2019                  1501402  ...    B     A    B
# 7  190001004904    2019                  1501402  ...    A     A    A
# 8  190001004986    2019                  1502400  ...    A     A    B
# 9  190001004989    2019                  1506807  ...    A     C    B
#
# [10 rows x 136 columns]

# %% [markdown]
# ### Observando as dimensões do dataframe - linhas e colunas

# %%
dados.columns
# Out:
# Index(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        ...
#        'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024',
#        'Q025'],
#       dtype='object', length=136)

# %%
dados.dtypes
# Out:
# NU_INSCRICAO                int64
# NU_ANO                      int64
# CO_MUNICIPIO_RESIDENCIA     int64
# NO_MUNICIPIO_RESIDENCIA    object
# CO_UF_RESIDENCIA            int64
#                             ...
# Q021                       object
# Q022                       object
# Q023                       object
# Q024                       object
# Q025                       object
# Length: 136, dtype: object

# %%
dados.info
# Out:
# <bound method DataFrame.info of         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0       190001004661    2019                  1506138  ...    A     B    B
# 1       190001004674    2019                  1504208  ...    A     A    B
# 2       190001004722    2019                  1501402  ...    A     A    B
# 3       190001004735    2019                  1507300  ...    A     A    B
# 4       190001004776    2019                  1500800  ...    A     A    B
# ...              ...     ...                      ...  ...  ...   ...  ...
# 127375  190006120035    2019                  3142700  ...    A     B    B
# 127376  190006120036    2019                  2902807  ...    A     B    B
# 127377  190006120037    2019                  2927408  ...    A     A    B
# 127378  190006120060    2019                  2930709  ...    A     A    A
# 127379  190006120170    2019                  3106200  ...    B     A    B
#
# [127380 rows x 136 columns]>

# %%
dados.index
# Out:
# RangeIndex(start=0, stop=127380, step=1)

# %% [markdown]
# ### Vendo o nome das colunas do dataframe

# %%
dados.columns
# Out:
# Index(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        ...
#        'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024',
#        'Q025'],
#       dtype='object', length=136)

# %% [markdown]
# ## Categorize os seus dados

# %% [markdown]
# Os nossos atributos podem assumir diversos valores e por isso são chamados de variáveis.
#
# As variáveis podem ser classificadas entre:
#
# variáveis qualitativas:  qualidade
#
#     ordinal - pode-se estabelecer uma ordem entre as categorias: Q001 e Q002
#
#     nominal - não é possível hierarquizar as categorias: TP_SEXO
#
# variáveis quantitativas: contagens e medidas
#
#     discretos - contagem discreta formada por inteiros: 'NU_IDADE'
#
#     contínuos - contagem contínua formada por inteiros: 'NU_NOTA_CN' e 'NU_NOTA_CH'

# %% [markdown]
# <img src='img/variaveis.png' width='70%'>

# %% [markdown]
# ### Selecionando SubConjuntos do Dataframe

# %% [markdown]
# Um subconjunto bidimensional de um dataframe, também será um dataframe.
#
# Quando este subconjunto for unidimensional o seu tipo será um objeto do tipo Pandas Series. Diversos são as operações disponíveis para lidar com Series.
#
# Veja a documentação em: https://pandas.pydata.org/pandas-docs/stable/reference/series.html

# %%
#import pandas as pd
#dados = pd.read_csv("/content/drive/MyDrive/INF032/DataSet Enem2019/microdados_sample.csv")
pd.Series([dados, 2]).values
# Out:
# array([        NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0       190001004661    2019                  1506138  ...    A     B    B
# 1       190001004674    2019                  1504208  ...    A     A    B
# 2       190001004722    2019                  1501402  ...    A     A    B
# 3       190001004735    2019                  1507300  ...    A     A    B
# 4       190001004776    2019                  1500800  ...    A     A    B
# ...              ...     ...                      ...  ...  ...   ...  ...
# 127375  190006120035    2019                  3142700  ...    A     B    B
# 127376  190006120036    2019                  2902807  ...    A     B    B
# 127377  190006120037    2019                  2927408  ...    A     A    B
# 127378  190006120060    2019                  2930709  ...    A     A    A
# 127379  190006120170    2019                  3106200  ...    B     A    B
#
# [127380 rows x 136 columns],
#        2], dtype=object)

# %%
pd.Series([dados]).nbytes
# Out:
# 8

# %%
pd.Series([dados]).dtypes
# Out:
# dtype('O')

# %%
pd.Series([dados])
# Out:
# 0            NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RES...
# dtype: object

# %% [markdown]
# ### Identificando o domínio de uma coluna

# %%
dados['NU_IDADE']
# Out:
# 0         17
# 1         23
# 2         35
# 3         23
# 4         16
#           ..
# 127375    17
# 127376    18
# 127377    22
# 127378    26
# 127379    19
# Name: NU_IDADE, Length: 127380, dtype: int64

# %%
dados.loc[0:2]
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
#
# [3 rows x 136 columns]

# %%
dados.loc[dados['NU_IDADE']<=20]
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0       190001004661    2019                  1506138  ...    A     B    B
# 4       190001004776    2019                  1500800  ...    A     A    B
# 5       190001004841    2019                  1503606  ...    A     B    B
# 7       190001004904    2019                  1501402  ...    A     A    A
# 8       190001004986    2019                  1502400  ...    A     A    B
# ...              ...     ...                      ...  ...  ...   ...  ...
# 127371  190006119825    2019                  2506103  ...    A     A    B
# 127373  190006119987    2019                  2925204  ...    A     A    A
# 127375  190006120035    2019                  3142700  ...    A     B    B
# 127376  190006120036    2019                  2902807  ...    A     B    B
# 127379  190006120170    2019                  3106200  ...    B     A    B
#
# [77523 rows x 136 columns]

# %% [markdown]
# ### Verificando a frequencia de inscritos por faixa de renda

# %%
dados.loc[dados['Q006']=='D']
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 9       190001004989    2019                  1506807  ...    A     C    B
# 21      190001005327    2019                  1501402  ...    A     B    A
# 27      190001005569    2019                  1502103  ...    A     A    B
# 28      190001005647    2019                  1500107  ...    A     B    B
# 29      190001005649    2019                  1507300  ...    A     C    B
# ...              ...     ...                      ...  ...  ...   ...  ...
# 127296  190006115959    2019                  3151206  ...    A     B    A
# 127297  190006115985    2019                  3170206  ...    B     A    B
# 127299  190006116012    2019                  3143302  ...    A     D    B
# 127348  190006118469    2019                  1501402  ...    A     A    A
# 127354  190006118692    2019                  2919405  ...    A     B    B
#
# [12555 rows x 136 columns]

# %% [markdown]
# ## Avaliação Visual Com Histograma

# %% [markdown]
# ### "Plot" dos dados de uma coluna

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

dados['NU_IDADE'].plot()
#dados_df['NU_IDADE'].hist(bins=30)

# %% [markdown]
# ### Avaliação Visual da Idade (Histograma)

# %%
dados['NU_IDADE'].hist(bins=25, color='red')

# %% [markdown]
# ### Investigando Idade dos Treineiros

# %%
dados.head()
#dados_df.groupby("SG_UF_RESIDENCIA").NU_NOTA_REDACAO.mean().round(2)
dados.groupby("IN_TREINEIRO").NU_NOTA_REDACAO.mean().round(2)
# Out:
# IN_TREINEIRO
# 0    571.54
# 1    571.72
# Name: NU_NOTA_REDACAO, dtype: float64

# %% [markdown]
# ### Avaliação Visual da Nota da Redação

# %%
dados.head()
dados.groupby("Q006").NU_NOTA_REDACAO.mean().round(2)
#descio padrão
#dados_df.groupby("Q006").NU_NOTA_REDACAO.std().round(2)
# Out:
# Q006
# A    495.55
# B    514.88
# C    544.30
# D    565.42
# E    580.56
# F    606.57
# G    620.69
# H    648.21
# I    660.34
# J    674.78
# K    683.69
# L    700.68
# M    693.12
# N    703.36
# O    720.40
# P    731.66
# Q    740.54
# Name: NU_NOTA_REDACAO, dtype: float64

# %% [markdown]
# ### Avaliação Visual da Nota de Linguagens e Códigos

# %%
dados['NU_NOTA_LC'].hist(histtype='bar', bins=30, align='mid', color='orange')

# %% [markdown]
# ### Agrupando as notas por estados e tirando a média da nota de Redação

# %% [markdown]
# Um objeto GroupBy pode ser usado para calcular valores (contagem, máximos, mínimos, média) sobre dados agrupados por algum atributo.
#
# Veja os atributos e métodos dos objetos GroupBy em: https://pandas.pydata.org/pandas-docs/stable/reference/groupby.html

# %%
dados.columns
# Out:
# Index(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        ...
#        'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024',
#        'Q025'],
#       dtype='object', length=136)

# %%
dados.groupby("SG_UF_RESIDENCIA").NU_NOTA_REDACAO.mean().round(2)
# Out:
# SG_UF_RESIDENCIA
# AC    516.27
# AL    553.69
# AM    502.99
# AP    522.55
# BA    555.64
# CE    569.70
# DF    582.79
# ES    590.68
# GO    572.67
# MA    539.34
# MG    595.75
# MS    553.82
# MT    532.53
# PA    552.67
# PB    576.89
# PE    563.26
# PI    562.13
# PR    569.25
# RJ    596.51
# RN    579.25
# RO    524.39
# RR    514.95
# RS    578.67
# SC    579.83
# SE    591.41
# SP    589.49
# TO    552.94
# Name: NU_NOTA_REDACAO, dtype: float64

# %% [markdown]
# ### Criando Categorias por faixas de valores

# %%
print("Notas minimas: ", dados_df.NU_NOTA_REDACAO.min())
print("Notas maximasmas: ", dados_df.NU_NOTA_REDACAO.max())
# Out:
# Notas minimas:  0.0
# Notas maximasmas:  1000.0

# %%
faixas=[0, 200, 400, 600, 800, 1000]
rotulos = ['0 a 200', '200 a 400', '400 a 600', '600 a 800', '800 a 1000']
redacao_classes = pd.cut(x=dados_df.NU_NOTA_REDACAO, bins=faixas, labels=rotulos, include_lowest=True)
redacao_classes.value_counts(sort=False, normalize=True) * 100
# Out:
# 0 a 200        3.750395
# 200 a 400     10.952337
# 400 a 600     45.700356
# 600 a 800     29.789990
# 800 a 1000     9.806921
# Name: NU_NOTA_REDACAO, dtype: float64

# %% [markdown]
# ## Resumindo os dados

# %% [markdown]
# ### Medidas de Tendência Central

# %%
print(dados.NU_NOTA_REDACAO.mean())
print(dados.NU_NOTA_REDACAO.median())
print(dados.NU_NOTA_REDACAO.mode()[0])
# Out:
# 571.5700253970197
# 580.0
# 600.0

# %%
salaA = [2.5, 2.5, 10]
salaB = [5, 5, 5]

print("Médiana sala A:", np.median(salaA))
print("Médiana sala B:", np.median(salaB))
# Out:
# Médiana sala A: 2.5
# Médiana sala B: 5.0

# %% [markdown]
# ### Assimetria e medidas de Tendência Central
#
# <img src='img/assimetria.png' width='70%'>

# %%
salaA = [2.5, 2.5, 10]
salaB = [5, 5, 5]

print("Média sala A:", np.mean(salaA))
print("Média sala B:", np.mean(salaB))
# Out:
# Média sala A: 5.0
# Média sala B: 5.0

# %% [markdown]
# ### Medidas de Dispersão

# %%
dados_idade = dados[['NU_IDADE']].copy()
dados_idade['DIST_MEDIA'] = np.power(dados_idade.NU_IDADE - dados_idade.NU_IDADE.mean(), 2)
#dados_idade['DIST_MEDIA'] = np.power(dados_idade.NU_IDADE - dados_idade.NU_IDADE.mean())
dados_idade.DIST_MEDIA.sum() / dados_idade.DIST_MEDIA.count()
# Out:
# 56.23016911276681

# %%
print(dados.NU_IDADE.mad())
print(dados.NU_IDADE.var())
print(dados.NU_IDADE.std())
# Out:
# 5.247312957614659
# 56.230610552647455
# 7.498707258764504

# %% [markdown]
# ### Medidas Separatrizes:

# %%
dados.NU_IDADE.quantile([0.25, 0.50, 0.75, 1])
# Out:
# 0.25    18.0
# 0.50    19.0
# 0.75    24.0
# 1.00    82.0
# Name: NU_IDADE, dtype: float64

# %% [markdown]
# ###  Medidas Separatrizes: Percentiles e Quartiles

# %%
nota_sup = dados.NU_NOTA_REDACAO.quantile(0.95)
print(f'Apenas 5% dos alunos tiraram acima de {nota_sup} em redação')
# Out:
# Apenas 5% dos alunos tiraram acima de 880.0 em redação

# %% [markdown]
# ### Estatísticas Descritivas das Notas

# %%
provas=['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_MT','NU_NOTA_LC', 'NU_NOTA_REDACAO']

dados[provas].describe()
# Out:
#          NU_NOTA_CN    NU_NOTA_CH    NU_NOTA_MT    NU_NOTA_LC  NU_NOTA_REDACAO
# count  92758.000000  98043.000000  92758.000000  98043.000000     98043.000000
# mean     477.964015    507.365912    523.555206    520.463928       571.570025
# std       76.296099     82.972839    109.416939     64.556578       188.076455
# min        0.000000      0.000000      0.000000      0.000000         0.000000
# 25%      418.000000    447.900000    435.300000    483.700000       480.000000
# 50%      470.200000    510.900000    501.600000    526.100000       580.000000
# 75%      533.300000    567.100000    598.200000    565.100000       680.000000
# max      797.300000    809.400000    985.000000    801.700000      1000.000000

# %%
provas
# Out:
# ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_MT', 'NU_NOTA_LC', 'NU_NOTA_REDACAO']

# %%
notas_cn = dados['NU_NOTA_CN'].value_counts()
idade_cn = dados['NU_IDADE'].value_counts()

notas_cn.hist(bins=25)
#idade_cn.hist(bins=25)

#plt.subplot(2, 2, 1)
#plt.plot()

#dados.query('NU_NOTA_CN').NU_IDADE.plot(kind='hist', figsize=(10, 5), color='red', label='notas_cn')
#red = mpatches.Patch(color='red', label='CN')

#plt.legend(handles=[red])

#plt.xlabel('IDADES')
#plt.ylabel('NOTAS CN')
#plt.title('NOTA_CN vs IDADE')

# %% [markdown]
# ## Avaliação Visual Com Boxplots

# %% [markdown]
# O uso de boxplot permite visualizar medidas centrais, de dispersão e outliers (medidas discrepantes), além da assimetria da distribuição
#
# <img src='img/boxplot.png' width='65%'>

# %% [markdown]
# ### Visualizando a distribuição das notas de redação

# %%
dados_df.NU_NOTA_REDACAO.plot.box(figsize=(12,8))

# %% [markdown]
# ### Visualizando a distribuição das notas

# %%
dados_df[provas].plot.box(figsize=(12,8))

# %% [markdown]
# ## <font color="#1D334A" size=8>Aula 02 - Análise Exploratória: Visualizando os dados </font>

# %% [markdown]
# ### Biblioteca Seaborn: Visualizando a distribuição das notas de redação II

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import GridSpec

fig = plt.figure(constrained_layout=True)
gs = GridSpec(1,2, figure=fig)

ax0 = fig.add_subplot(gs[0, 0])

sns.set_style("whitegrid")
ax = sns.boxplot(data=dados_df.NU_NOTA_REDACAO, orient='h', palette='Accent')
ax.figure.set_size_inches(12,6)
ax.set_title('Distribuição das Notas de redação - ENEM 2019', fontsize=20)
ax.set_xlabel('Notas', fontsize=16)
ax.set_xlim(xmin=0, xmax=dados_df.NU_NOTA_REDACAO.max() * 1.05)
ax.grid(True)

# %% [markdown]
# Paleta de Cores Pré-Fixadas no seaborn
#
# 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'

# %% [markdown]
# ## Explorando os dados de pessoas novas

# %%
dados_df.query('NU_IDADE <= 14').SG_UF_RESIDENCIA.value_counts()
# Out:
# PE    18
# CE    15
# BA    14
# PA    12
# SP    11
# MG    11
# MA     9
# GO     7
# PB     7
# PI     7
# DF     4
# MT     4
# AM     4
# SE     3
# PR     3
# TO     3
# SC     2
# RO     2
# AL     2
# RN     1
# RS     1
# RJ     1
# MS     1
# AP     1
# AC     1
# ES     1
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
dados_df.query('NU_IDADE <= 14').SG_UF_RESIDENCIA.value_counts(normalize=True) * 100
# Out:
# PE    12.413793
# CE    10.344828
# BA     9.655172
# PA     8.275862
# SP     7.586207
# MG     7.586207
# MA     6.206897
# GO     4.827586
# PB     4.827586
# PI     4.827586
# DF     2.758621
# MT     2.758621
# AM     2.758621
# SE     2.068966
# PR     2.068966
# TO     2.068966
# SC     1.379310
# RO     1.379310
# AL     1.379310
# RN     0.689655
# RS     0.689655
# RJ     0.689655
# MS     0.689655
# AP     0.689655
# AC     0.689655
# ES     0.689655
# Name: SG_UF_RESIDENCIA, dtype: float64

# %%
IdadeInscMenor14 = pd.DataFrame()
IdadeInscMenor14['QTDE'] = dados_df.query('NU_IDADE <= 14').SG_UF_RESIDENCIA.value_counts()
IdadeInscMenor14['PCT'] = dados_df.query('NU_IDADE <= 14').SG_UF_RESIDENCIA.value_counts()

IdadeInscMenor14
# Out:
#     QTDE  PCT
# PE    18   18
# CE    15   15
# BA    14   14
# PA    12   12
# SP    11   11
# MG    11   11
# MA     9    9
# GO     7    7
# PB     7    7
# PI     7    7
# DF     4    4
# MT     4    4
# AM     4    4
# SE     3    3
# PR     3    3
# TO     3    3
# SC     2    2
# RO     2    2
# AL     2    2
# RN     1    1
# RS     1    1
# RJ     1    1
# MS     1    1
# AP     1    1
# AC     1    1
# ES     1    1

# %% [markdown]
# ## Escolhendo a melhor visualização para estes dados

# %% [markdown]
# ## Gráfico de Pizza - Pie Chart

# %%
IdadeInscMenor14.PCT.plot.pie()

# %%
import seaborn as sns
sns.set_style('whitegrid')

fig, ax = plt.subplots()
fig.set_size_inches(10, 8)
ax.pie(IdadeInscMenor14.QTDE, 
       colors=sns.color_palette(palette="pastel", n_colors=30, desat=None),
       labels=IdadeInscMenor14.index)
plt.title('IF dos incritos com menos de 14 anos', fontsize=25)
plt.show()

# %%
###fazer gráfico de barras
#fig, ax = plt.subplots()
#fig.set_size_inches(10, 8)
#ax.bar(IdadeInscMenor14.QTDE, 
 #      colors=sns.color_palette(palette="husl", n_colors=30, desat=None),
 #      labels=IdadeInscMenor14.index)
#plt.title('IF dos incritos com menos de 14 anos', fontsize=25)
#plt.show()

fig, ax = plt.subplots()
fig.set_size_inches(10, 8)
ax.bar(IdadeInscMenor14.QTDE, IdadeInscMenor14.PCT, width=0.8, bottom=None)
plt.title('IF dos incritos com menos de 14 anos', fontsize=25)
plt.show()

# %% [markdown]
# ## Análise Exploratória - Avaliando Notas x Renda Familiar

# %% [markdown]
# ### Boxplot da Q006 x Nota Matemática

# %%
sns.set_style('whitegrid')
faixas_salariais = dados_df.Q006.unique()
faixas_salariais.sort()
ax = sns.boxplot(x = 'Q006', y = 'NU_NOTA_MT', data=dados_df,
                order = faixas_salariais, palette=sns.color_palette(palette='husl'))

ax.figure.set_size_inches(16, 10)
ax.set_title('Distribuição das Notas de Matematica Considerando as faixas de renda')
# Out:
# Text(0.5, 1.0, 'Distribuição das Notas de Matematica Considerando as faixas de renda')

# %% [markdown]
# ### Criando Coluna com a soma das notas de todas as provas

# %%
provas=['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_MT','NU_NOTA_LC', 'NU_NOTA_REDACAO']
dados_df['NU_NOTA_TOTAL'] = dados_df[provas].sum(axis=1)
provas.append('NU_NOTA_TOTAL')
dados_df[provas].head()
# Out:
#    NU_NOTA_CN  NU_NOTA_CH  ...  NU_NOTA_REDACAO  NU_NOTA_TOTAL
# 0       435.6       512.3  ...            420.0         2288.9
# 1         NaN       409.3  ...            400.0         1184.6
# 2       423.2       499.1  ...            560.0         2350.5
# 3       426.2       578.1  ...            500.0         2555.7
# 4       516.5       571.3  ...            780.0         2803.5
#
# [5 rows x 6 columns]

# %% [markdown]
# ### Escrevendo Função para plotar um boxplot da Questão 006 x Coluna Indicada

# %%
def boxplot_Q006(dados : pd.DataFrame, col_ref : str, title : str, ax : plt.Axes = None) :
    sns.set_style('whitegrid')
    faixas_salariais = dados_df.Q006.unique()
    faixas_salariais.sort()
    if(ax == None) :
        ax = sns.boxplot(x = 'Q006', y = 'NU_NOTA_MT', data=dados_df,
                order = faixas_salariais, palette=sns.color_palette(palette='husl'))
    else :
        sns.boxplot(x = 'Q006', y = col_ref, data=dados_df,
                order = faixas_salariais, palette=sns.color_palette(palette='husl'),
                ax=ax)
    ax.set_ylim(ymin=0, ymax=ymax)
    ax.figure.set_size_inches(16, 10)
    ax.set_title('Distribuição das Notas de Matematica Considerando as faixas de renda')
    return ax

# %% [markdown]
# ### Plotando a relação das Classes Sociais com a Nota Total do ENEM

# %%
sns.set_style('whitegrid')
faixas_salariais = dados_df.Q006.unique()
faixas_salariais.sort()

ax = boxplot_Q006(dados=dados_df, col_ref = 'NU_NOTA_TOTAL',
                 title = 'Distribuição das Notas de Matematica Considerando as faixas de renda',
                 ymax=dados_df.NU_NOTA_TOTAL.max() * 1.05)
ax
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-059ba02c4ddf> in <module>()
#       5 ax = boxplot_Q006(dados=dados_df, col_ref = 'NU_NOTA_TOTAL',
#       6                  title = 'Distribuição das Notas de Matematica Considerando as faixas de renda',
# ----> 7                  ymax=dados_df.NU_NOTA_TOTAL.max() * 1.05)
#       8 ax
#
# TypeError: boxplot_Q006() got an unexpected keyword argument 'ymax'

# %%
#teste de gráficos lado a lado
N_points = idade_cn.value_counts()
n_bins = 20

# Generate a normal distribution, center at x=0 and y=5
x = idade_cn
y = notas_cn

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)

# We can set the number of bins with the `bins` kwarg
axs[0].hist(x, bins=n_bins)
axs[1].hist(y, bins=n_bins)
# Out:
# (array([756., 207., 242., 167., 155., 211., 138., 264., 204., 268., 372.,
#         243., 282., 154.,  97.,  67.,  29.,  11.,   2.,   3.]),
#  array([ 1. ,  4.4,  7.8, 11.2, 14.6, 18. , 21.4, 24.8, 28.2, 31.6, 35. ,
#         38.4, 41.8, 45.2, 48.6, 52. , 55.4, 58.8, 62.2, 65.6, 69. ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# ### Plotando a relação das Classes Sociais com a Nota de cada prova

# %%
#pesquisar one hot https://en.wikipedia.org/wiki/One-hot
dados_NU_NOTA_CN = dados[['NU_NOTA_CN']]
dados_onehot_notas_cn = pd.get_dummies(dados_NU_NOTA_CN.NU_NOTA_CN)

dados_NU_NOTA_CN
# Out:
#         NU_NOTA_CN
# 0            435.6
# 1              NaN
# 2            423.2
# 3            426.2
# 4            516.5
# ...            ...
# 127375       502.4
# 127376       449.1
# 127377         NaN
# 127378       564.7
# 127379       466.7
#
# [127380 rows x 1 columns]

# %% [markdown]
# ## Examinando o comportamento do boxplot através do histograma de notas

# %%
sns.set_style('whitegrid')
ax = sns.histplot(data=dados_df.NU_NOTA_TOTAL,
                 palette=sns.color_palette(palette='husl'))
ax.set_title('Distribuição da frequência da nota total das provas', fontsize=25)
ax.figure.set_size_inches(12, 6)

# %% [markdown]
# ## Examinando o significado da moda (Nota 0)

# %%
dados_df.query('NU_NOTA_TOTAL == 0')[provas]
# Out:
#         NU_NOTA_CN  NU_NOTA_CH  ...  NU_NOTA_REDACAO  NU_NOTA_TOTAL
# 10             NaN         NaN  ...              NaN            0.0
# 11             NaN         NaN  ...              NaN            0.0
# 26             NaN         NaN  ...              NaN            0.0
# 38             NaN         NaN  ...              NaN            0.0
# 40             NaN         NaN  ...              NaN            0.0
# ...            ...         ...  ...              ...            ...
# 127351         NaN         NaN  ...              NaN            0.0
# 127365         NaN         NaN  ...              NaN            0.0
# 127366         NaN         NaN  ...              NaN            0.0
# 127368         NaN         NaN  ...              NaN            0.0
# 127374         NaN         NaN  ...              NaN            0.0
#
# [29162 rows x 6 columns]

# %%
uma_presenca = dados_df.query('TP_PRESENCA_CH == 1 | TP_PRESENCA_CH == 1 | TP_PRESENCA_LC == 1 | TP_PRESENCA_LC == 1')
presenca_total = dados_df.query('TP_PRESENCA_CH == 1 & TP_PRESENCA_CH == 1 & TP_PRESENCA_LC == 1 & TP_PRESENCA_LC == 1')
presenca_total
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0       190001004661    2019                  1506138  ...    A     B    B
# 1       190001004674    2019                  1504208  ...    A     A    B
# 2       190001004722    2019                  1501402  ...    A     A    B
# 3       190001004735    2019                  1507300  ...    A     A    B
# 4       190001004776    2019                  1500800  ...    A     A    B
# ...              ...     ...                      ...  ...  ...   ...  ...
# 127375  190006120035    2019                  3142700  ...    A     B    B
# 127376  190006120036    2019                  2902807  ...    A     B    B
# 127377  190006120037    2019                  2927408  ...    A     A    B
# 127378  190006120060    2019                  2930709  ...    A     A    A
# 127379  190006120170    2019                  3106200  ...    B     A    B
#
# [98043 rows x 136 columns]

# %%
dados_df.query('NU_NOTA_TOTAL == 1')[['TP_PRESENCA_CH', 'TP_PRESENCA_CH']]
# Out:
# Empty DataFrame
# Columns: [TP_PRESENCA_CH, TP_PRESENCA_CH]
# Index: []

# %%
sns.set_style('whitegrid')
ax = sns.histplot(data=uma_presenca,
                 palette=sns.color_palette(palette='pastel'))
ax.set_title('Distribuição da frequência da nota total das provas', fontsize=25)
ax.figure.set_size_inches(12, 6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-1d23bef42ce9> in <module>()
#       1 sns.set_style('whitegrid')
#       2 ax = sns.histplot(data=uma_presenca,
# ----> 3                  palette=sns.color_palette(palette='pastel'))
#       4 ax.set_title('Distribuição da frequência da nota total das provas', fontsize=25)
#       5 ax.figure.set_size_inches(12, 6)
#
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1393     )
#    1394
# -> 1395     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    1396
#    1397     if ax is None:
#
# /usr/local/lib/python3.6/dist-packages/seaborn/_core.py in map(cls, plotter, *args, **kwargs)
#      51         # This method is assigned the __init__ docstring
#      52         method_name = "_{}_map".format(cls.__name__[:-7].lower())
# ---> 53         setattr(plotter, method_name, cls(plotter, *args, **kwargs))
#      54         return plotter
#      55
#
# /usr/local/lib/python3.6/dist-packages/seaborn/_core.py in __init__(self, plotter, palette, order, norm)
#     117                 cmap = norm = None
#     118                 levels, lookup_table = self.categorical_mapping(
# --> 119                     data, palette, order,
#     120                 )
#     121
#
# /usr/local/lib/python3.6/dist-packages/seaborn/_core.py in categorical_mapping(self, data, palette, order)
#     202                 if len(palette) != n_colors:
#     203                     err = "The palette list has the wrong number of colors."
# --> 204                     raise ValueError(err)
#     205                 colors = palette
#     206             else:
#
# ValueError: The palette list has the wrong number of colors.

# %% [markdown]
# ## Analisando o comportamento considerando treineiros

# %% [markdown]
# ## <font color="#1D334A" size=8>Aula 03 - Distribuições e Correlações</font>

# %% [markdown]
# ## Avaliando Assimetrias

# %%
sns.set_style('whitegrid')
#ax = sns.histplot(dados_pv_completas.query('NU_NOTA_REDACAO > 0').NU_NOTA_REDACAO, kde=True, bins=45)
ax = sns.histplot(presenca_total.query('NU_NOTA_REDACAO > 0').NU_NOTA_REDACAO, kde=True, bins=45)
ax.set_title('Distribuição de Frequência da Nota de Redação', fontsize=20)
ax.figure.set_size_inches(12, 6)

# %%
print(presenca_total.NU_NOTA_REDACAO.mean())
print(presenca_total.NU_NOTA_REDACAO.median())
print(presenca_total.NU_NOTA_REDACAO.mode()[0])
# Out:
# 571.5700253970197
# 580.0
# 600.0

# %%
sns.set_style('whitegrid')
#ax = sns.histplot(dados_pv_completas.query('NU_NOTA_REDACAO > 0').NU_NOTA_REDACAO, kde=True, bins=45)
ax = sns.histplot(presenca_total.query('NU_NOTA_MT > 0').NU_NOTA_MT, kde=True, bins=45)
ax.set_title('Distribuição de Frequência da Nota de Matematica', fontsize=20)
ax.figure.set_size_inches(12, 6)

# %%
print(presenca_total.NU_NOTA_MT.mean())
print(presenca_total.NU_NOTA_MT.median())
print(presenca_total.NU_NOTA_MT.mode()[0])
# Out:
# 523.6812803250558
# 501.8
# 427.1

# %%
sns.set_style('whitegrid')
#ax = sns.histplot(dados_pv_completas.query('NU_NOTA_REDACAO > 0').NU_NOTA_REDACAO, kde=True, bins=45)
ax = sns.histplot(presenca_total.query('NU_NOTA_LC > 0').NU_NOTA_LC, kde=True, bins=45)
ax.set_title('Distribuição de Frequência da Nota de Linguagens e Códigos', fontsize=20)
ax.figure.set_size_inches(12, 6)

# %%
print(presenca_total.NU_NOTA_LC.mean())
print(presenca_total.NU_NOTA_LC.median())
print(presenca_total.NU_NOTA_LC.mode()[0])
# Out:
# 520.4639280723744
# 526.1
# 0.0

# %%
#pre processamento 
from sklearn.preprocessing import PowerTransformer
presenca_total['NU_NOTA_MT_LOG'] = np.log(presenca_total['NU_NOTA_MT'] + 1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
sns.set_style('whitegrid')
#ax = sns.histplot(dados_pv_completas.query('NU_NOTA_REDACAO > 0').NU_NOTA_REDACAO, kde=True, bins=45)
ax = sns.histplot(presenca_total.NU_NOTA_MT_LOG, kde=True, bins=45)
ax.set_title('Distribuição de Frequência da Nota de Matematica', fontsize=20)
ax.figure.set_size_inches(12, 6)

# %%
#pre processamento 
###!pip install sktlearn
from sklearn.preprocessing import PowerTransformer
presenca_total['NU_NOTA_MT_TRANS'] = PowerTransformer(method='box-cox').fit_transform(presenca_total([['NU_NOTA_MT']]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-90e0fd622a5d> in <module>()
#       2 ###!pip install sktlearn
#       3 from sklearn.preprocessing import PowerTransformer
# ----> 4 presenca_total['NU_NOTA_MT_TRANS'] = PowerTransformer(method='box-cox').fit_transform(presenca_total([['NU_NOTA_MT']]))
#
# TypeError: 'DataFrame' object is not callable

# %%
presenca_total.NU_NOTA_TOTAL
# Out:
# 0         2288.9
# 1         1184.6
# 2         2350.5
# 3         2555.7
# 4         2803.5
#            ...
# 127375    2867.4
# 127376    2218.5
# 127377    1453.9
# 127378    2573.9
# 127379    2287.8
# Name: NU_NOTA_TOTAL, Length: 98043, dtype: float64

# %%
#o fato da pessoa ter ou não acesso a internet, muda o comportamento das notas, qual o impacto?
sns.set_style('whitegrid')
#ax = sns.histplot(dados_pv_completas.query('NU_NOTA_REDACAO > 0').NU_NOTA_REDACAO, kde=True, bins=45)
ax = sns.histplot(presenca_total.query("Q025 == 'A'").NU_NOTA_TOTAL, kde=True, bins=45, color='orange', label='Sem acesso')
ax = sns.histplot(presenca_total.query("Q025 == 'B'").NU_NOTA_TOTAL, kde=True, bins=45, color='green', label='Com acesso', ax=ax)
ax.set_title('Distribuição de Frequência da Nota de Total x Q025', fontsize=20)
ax.figure.set_size_inches(12, 6)
ax.legend()
ax

# %%
presenca_total.Q025
# Out:
# 0         B
# 1         B
# 2         B
# 3         B
# 4         B
#          ..
# 127375    B
# 127376    B
# 127377    B
# 127378    A
# 127379    B
# Name: Q025, Length: 98043, dtype: object

# %%
sns.set_style('whitegrid')
#ax = sns.histplot(dados_pv_completas.query('NU_NOTA_REDACAO > 0').NU_NOTA_REDACAO, kde=True, bins=45)
ax = sns.histplot(presenca_total.query('NU_NOTA_MT > 0').NU_NOTA_MT, kde=True, bins=45, color='green', stat='density', cumulative=True)
ax.set_title('Distribuição de Frequência Cumulativa da Nota de Matematica', fontsize=20)
ax.figure.set_size_inches(12, 6)

# %%
#o gráfico acima mostra a visão do quantile
presenca_total.NU_NOTA_MT.quantile(0.97)
# Out:
# 757.1

# %% [markdown]
# ## Realizando comparação de comportamento pela frequência de histogramas

# %%
#passar gráfico de frequência para aqui

# %% [markdown]
# ### Usando histograma para avaliar medidas separatrizes da nota de redaçao

# %%
#colocar gráfico aqui

# %% [markdown]
# ## Correlações

# %% [markdown]
# ### Correlação entre Notas de MT x Notas de CN

# %%
fig , ax0 = plt.subplots()
fig.set_size_inches(10, 10)
sns.scatterplot(x = 'NU_NOTA_MT', y = 'NU_NOTA_CN', data = presenca_total, color='#ffaa00', ax=ax0)
ax0.set_xlim(0, 1050)
ax0.set_ylim(0, 1050)
ax0.set_xlabel('Nota de matematica', fontsize=22)
ax0.set_ylabel('Nota de Ciências naturais', fontsize=22)
# Out:
# Text(0, 0.5, 'Nota de Ciências naturais')

# %%
fig , ax0 = plt.subplots()
fig.set_size_inches(10, 10)
sns.scatterplot(x = 'NU_NOTA_MT', y = 'NU_NOTA_CN', data = presenca_total.query('NU_NOTA_MT > 650'), color='#ffaa00', ax=ax0)
ax0.set_xlim(0, 1050)
ax0.set_ylim(0, 1050)
ax0.set_xlabel('Nota de matematica', fontsize=22)
ax0.set_ylabel('Nota de Ciências naturais', fontsize=22)
# Out:
# Text(0, 0.5, 'Nota de Ciências naturais')

# %%
presenca_total[['NU_NOTA_MT', 'NU_NOTA_CN', 'NU_NOTA_LC']].corr()
# Out:
#             NU_NOTA_MT  NU_NOTA_CN  NU_NOTA_LC
# NU_NOTA_MT    1.000000    0.650386    0.587986
# NU_NOTA_CN    0.650386    1.000000    0.641998
# NU_NOTA_LC    0.587986    0.641998    1.000000

# %% [markdown]
# ### Correlação entre Notas

# %%
sns.set_style('whitegrid')
sns.set_palette('summer')
ax = sns.pairplot(data=presenca_total[provas])
ax.fig.suptitle('Correlação entre as Notas', y=1.05, fontsize=20)
# Out:
# Text(0.5, 1.05, 'Correlação entre as Notas')

# %% [markdown]
# ## Correlação entre Notas de MT x Notas de LC e uma terceira dimensão (acesso a internet)

# %%
fig , ax0 = plt.subplots()
fig.set_size_inches(10, 10)
sns.scatterplot(x = 'NU_NOTA_MT', y = 'NU_NOTA_CN', data = presenca_total, palette='summer_r', ax=ax0, hue='Q025', alpha=0.9)
ax0.set_xlim(0, 1050)
ax0.set_ylim(0, 1050)
ax0.set_xlabel('Nota de matematica', fontsize=22)
ax0.set_ylabel('Nota de Ciências naturais', fontsize=22)
# Out:
# Text(0, 0.5, 'Nota de Ciências naturais')

# %% [markdown]
# ## Correlação entre Notas - Pearson

# %% [markdown]
# Correlação é qualquer relação estatística (causal ou não causal) entre duas variáveis.
#
# Embora seja comumente denotada como a medida de relação entre duas variáveis aleatórias, correlação não implica causalidade.
#
# Correlações espúrias: https://www.tylervigen.com/spurious-correlations
#
#
# <img src='img/pearson.png' width='65%'>

# %%
#data frame do pandas
correlacao_notas = presenca_total[provas].corr()

# %%
fig , ax0 = plt.subplots()
fig.set_size_inches(10, 10)
sns.scatterplot(x = 'NU_NOTA_LC', y = 'NU_NOTA_CN', data = presenca_total, color='#ffaa00', ax=ax0)
ax0.set_xlim(0, 1050)
ax0.set_ylim(0, 1050)
ax0.set_xlabel('Nota de matematica', fontsize=22)
ax0.set_ylabel('Nota de Ciências naturais', fontsize=22)
# Out:
# Text(0, 0.5, 'Nota de Ciências naturais')

# %% [markdown]
# ## Interpretação dos valores da Correlação
#
# <img src='img/pearson02.png' width='65%'>

# %% [markdown]
# ## Visualização da Correlação entre Notas

# %%
ax = sns.heatmap(correlacao_notas, cmap='summer_r', square=True, annot=True)
ax.set_title('Mapa de correlação de Pearson das notas', fontsize=22, y=1.05)
# Out:
# Text(0.5, 1.05, 'Mapa de correlação de Pearson das notas')

# %%
fig = plt.figure(constrained_layout=True)
fig.set_size_inches(15, 5)
gs = GridSpec(1,2, figure=fig)

ax0 = fig.add_subplot(gs[0, 0])
ax1 = fig.add_subplot(gs[0, 1])
ax2 = fig.add_subplot(gs[0, 2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-78-6da59b21d5cd> in <module>()
#       6 ax0 = fig.add_subplot(gs[0, 0])
#       7 ax1 = fig.add_subplot(gs[0, 1])
# ----> 8 ax2 = fig.add_subplot(gs[0, 2])
#       9
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/gridspec.py in __getitem__(self, key)
#     228                 raise ValueError("unrecognized subplot spec")
#     229             num1, num2 = np.ravel_multi_index(
# --> 230                 [_normalize(k1, nrows, 0), _normalize(k2, ncols, 1)],
#     231                 (nrows, ncols))
#     232         else:  # Single key
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/gridspec.py in _normalize(key, size, axis)
#     216                     return key, key
#     217                 elif axis is not None:
# --> 218                     raise IndexError(f"index {orig_key} is out of bounds for "
#     219                                      f"axis {axis} with size {size}")
#     220                 else:  # flat index
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %% [markdown]
# ## <font color="#1D334A" size=8>Aula 04 - Regressão</font>

# %% [markdown]
# ### Selecionando os dados de variáveis quantitativas para regressão
# ### Convertendo dados de variáveis qualitativas ordinais

# %%
renda = {'A' : 0, 'B' : 1, 'C' : 2, 'D' : 3, 'E' : 4, 'F' : 5, 'G' : 6, 'H' : 7, 'I' : 8,
         'J' : 9, 'K' : 10, 'L' : 11, 'M' : 12, 'N' : 13, 'O': 14, 'P' : 15, 'Q' : 16}


var_quantitativas = ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_MT', 'NU_NOTA_LC', 'NU_NOTA_REDACAO', 
                     'NU_IDADE', 'Q006', 'Q005']
var_dependente =  'NU_NOTA_MT'
var_explicativas = ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_REDACAO', 
                     'NU_IDADE', 'Q006', 'Q005']

var_quantitativas_nt = ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC']
                     

dadosRL = presenca_total.query('NU_NOTA_CN > 0 & NU_NOTA_CH > 0 & NU_NOTA_MT > 0 & NU_NOTA_LC > 0 & NU_NOTA_REDACAO > 0').copy()
dadosRL = dadosRL[var_quantitativas]
dadosRL.dropna(axis='index', inplace=True)

dadosRL.Q006 = dadosRL.Q006.map(renda)

dadosRL
# Out:
#         NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_MT  ...  NU_IDADE  Q006  Q005
# 0            435.6       512.3       432.4  ...        17     1     4
# 2            423.2       499.1       427.2  ...        35     2     5
# 3            426.2       578.1       499.9  ...        23     1     1
# 4            516.5       571.3       424.5  ...        16     4     3
# 5            559.6       618.7       615.6  ...        18     2     2
# ...            ...         ...         ...  ...       ...   ...   ...
# 127373       480.4       501.5       386.7  ...        18     0     4
# 127375       502.4       559.6       539.7  ...        17     6     3
# 127376       449.1       380.9       418.2  ...        18     1     4
# 127378       564.7       416.2       455.7  ...        26     2     2
# 127379       466.7       425.5       438.5  ...        19     2     4
#
# [89905 rows x 8 columns]

# %% [markdown]
# ### Avaliando qualitativamente a relação entre a variável dependente e as variáveis explicativas

# %%
#colocar o codigo do print de RL
dadosRL.corr()
# Out:
#                  NU_NOTA_CN  NU_NOTA_CH  ...      Q006      Q005
# NU_NOTA_CN         1.000000    0.677967  ...  0.438791 -0.095528
# NU_NOTA_CH         0.677967    1.000000  ...  0.409411 -0.109375
# NU_NOTA_MT         0.649195    0.617953  ...  0.468312 -0.073869
# NU_NOTA_LC         0.649677    0.746054  ...  0.403691 -0.114644
# NU_NOTA_REDACAO    0.534331    0.552837  ...  0.344985 -0.054201
# NU_IDADE          -0.050672   -0.017547  ... -0.112097 -0.121994
# Q006               0.438791    0.409411  ...  1.000000 -0.002191
# Q005              -0.095528   -0.109375  ... -0.002191  1.000000
#
# [8 rows x 8 columns]

# %% [markdown]
#  ### Avaliando visualmente a relação entre a variável dependente e a variável explicativa

# %%
fig = plt.figure(constrained_layout=True)
fig.set_size_inches(15, 15)
gs = GridSpec(nclos=3, nrows=3, ficgure=fig)

#escrever código no print salvo no pc (scatterplot completo.png)

# %% [markdown]
# ### Escrevendo função de predição da nota de matemática

# %%
def nota_matematica(model : object, valores : pd.Series) :
    return model.params.x1 * valores[0] + \
           model.params.x2 * valores[1] + \
           model.params.x3 * valores[2] + \
           model.params.const 

def notas_matematica(model : object, valores : pd.DataFrame, explicativas : np.array) :
    notas = []
    for x in range(valores.shape[0]) :
      nota = nota_matematica(model, valores.loc[x, explicativas])
      notas.append(nota)
    return notas

# %% [markdown]
# ## Avaliação de Modelos Preditivos - Métricas

# %% [markdown]
# ### Escrevendo função de avaliação dos modelos

# %%
def veam(real : pd.Series, previtas : pd.Series) :
  ea = abs(real - previstas)
  veam = ea.mean()
  return veam

def reqm(real : pd.Series, previtas : pd.Series) :
  eq = ((real - previstas) ** 2)
  vreqm = (eq.mean()) ** (1/2)
  return vreqm

def r2(real : pd.Series, previtas : pd.Series) :

# %%
fig = plt.figure(constrained_layout=True)
fig.set_size_inches(15, 15)
gs = GridSpec(ncols=3, nrows=3, figure=fig)
ax0 = fig.add_subplot(gs[0, 0])
ax1 = fig.add_subplot(gs[0, 1])
ax2 = fig.add_subplot(gs[0, 2])
ax3 = fig.add_subplot(gs[1, 0])
ax4 = fig.add_subplot(gs[1, 1])
ax5 = fig.add_subplot(gs[1, 2])
ax6 = fig.add_subplot(gs[2, :])


sns.scatterplot(x = 'NU_NOTA_LC', y = 'NU_NOTA_MT', data = dadosRL, color='#BF9500', ax=ax0)
ax0.set_xlim(0, 1050)
ax0.set_ylim(0, 1050)
sns.scatterplot(x = 'NU_NOTA_CH', y = 'NU_NOTA_MT', data = dadosRL, color='#BF9500', ax=ax1)
ax1.set_xlim(0, 1050)
ax1.set_ylim(0, 1050)
sns.scatterplot(x = 'NU_NOTA_CN', y = 'NU_NOTA_MT', data = dadosRL, color='#BF9500', ax=ax2)
ax2.set_xlim(0, 1050)
ax2.set_ylim(0, 1050)
sns.scatterplot(x = 'NU_NOTA_REDACAO', y = 'NU_NOTA_MT', data = dadosRL, color='#BF9500', ax=ax3)
ax3.set_xlim(0, 1050)
ax3.set_ylim(0, 1050)

sns.scatterplot(x = 'Q006', y = 'NU_NOTA_MT', data = dadosRL, color='#BF9500', ax=ax4)
ax4.set_xlim(0, 17)
ax4.set_ylim(0, 1050)
sns.scatterplot(x = 'Q005', y = 'NU_NOTA_MT', data = dadosRL, color='#BF9500', ax=ax5)
ax5.set_xlim(0, 21)
ax5.set_ylim(0, 1050)
sns.scatterplot(x = 'NU_IDADE', y = 'NU_NOTA_MT', data = dadosRL, color='#BF9500', ax=ax6)
ax6.set_xlim(0, 100)
ax6.set_ylim(0, 1050)
# Out:
# (0.0, 1050.0)

# %% [markdown]
# dados
# ### Preparando dados de teste, dados fixos de treino (variável dependente) e dataset de resumo de predições / métricas

# %%
dadosRL.drop(labels=['NU_NOTA_REDACAO', 'NU_IDADE', 'Q006', 'Q005'], axis='columns', inplace=True)

# %%
#colocar numa linha acima
#dadosRL.drop(labels=['NU_NOTA-REDACAO', 'NU_IDADE', 'Q006', 'Q005'], axis='columns', inplace=True)

#reindexa os indices
dadosRL.index = range(dadosRL.shape[0])

size = dadosRL.shape[0]
treino_size = int(size * 0.80)

teste = dadosRL.loc[treino_size:, ]
teste.index = range(teste.shape[0])

#teste = dadosRL.loc[treino_size:, ]
#teste.index = range(dadosRL.shape[0])
#teste.shape

#size

# %% [markdown]
# ### Preparando dados de treino e gerando dados de avaliação da predição

# %%
import statsmodels.api as sm

teste = dadosRL.loc[treino_size:, ]
teste.index = range(dadosRL.shape[0])
#teste.shape

y = treino[var_dependente]
#y

#cada linha em um array - uso do column_statck() - pesquisar
X = np.column_stack((treino.NU_NOTA_CN, treino.NU_NOTA_CH, treino.NU_NOTA_LC))
X_Const = sm.add_constant(X)
#X_Const

model = sm.OLS(y, X_Const).fit()
print(model.summary())

# %%
nota_mt =  (0.5582 * 389.7) + (0.3158 * 490.8) + (0.3107 * 557.7) - 66.9060
print(nota_mt)
notas = pd.Series([389.7, 490.8, 557.7])
nota_mt_2 = nota_matematica(model, notas)
print(nota_mt_2)

#notas_matematica(model, teste, var_quantitativas_nt)
# Out:
# 478.89656999999994
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-e8f0ea5b4b5b> in <module>()
#       2 print(nota_mt)
#       3 notas = pd.Series([389.7, 490.8, 557.7])
# ----> 4 nota_mt_2 = nota_matematica(model, notas)
#       5 print(nota_mt_2)
#       6
#
# NameError: name 'model' is not defined

# %%
previstas_mt = notas_matematica(model, teste, var_quantitativas_nt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-afa77e75f1dd> in <module>()
# ----> 1 previstas_mt = notas_matematica(model, teste, var_quantitativas_nt)
#
# NameError: name 'model' is not defined

# %%
diff = (teste.NU_NOTA_MT - previstas_mt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-4308b789e8c9> in <module>()
# ----> 1 diff = (teste.NU_NOTA_MT - previstas_mt)
#
# NameError: name 'previstas_mt' is not defined

# %%
diff.mean()

# %% [markdown]
# > R-squared é o percentual da variação da variável dependente que um modelo linear consegue explicar. Varia de 0% (quando, o modelo não explica qualquer variação da variável resposta em torno do seu valor médio) a 100% (quando, o modelo explica toda variação da variável resposta em torno do seu valor médio)
#
# > Adjusted R-squared considera o número de termos no modelo. Quando um novo termo não melhora o R-squared, o modelo perde em liberdade e Adjusted R-squared diminui de valor.
#
# > F-statistic e Prob (F-statistic): O Teste F serve para verificar se ao menos uma variável explicativa contribui significativamente para o modelo. O Teste F compara um modelo sem preditores com o modelo de regressão especificado. Um modelo de regressão que não contém preditores também é conhecido como um modelo somente com o intercepto. Na prática ele compara se o seu modelo é melhor do que um outro que simplesmente retorna a média da variável dependente. o Prob (F-statistic) testa o nível de significância de rejeição da hipótese nula (o ajuste do modelo somente com o intercepto e seu modelo são iguais). Costuma-se considerar um valor abaixo de 5% como estatisticamente relevante.
#
# > P>|t| é o equivalente a Prob (F-statistic) considerando cada variável individualmente

# %% [markdown]
# ### Normalizando dados de treino e gerando dados de avaliação da predição do modelo normalizado

# %% [markdown]
# ### Função de Normalização

# %% [markdown]
# ### Avaliando dados gerados após normalização

# %% [markdown]
# ### Gerando comparação com um preditor baseline

# %% [markdown]
# ### Exibindo comparativo das métricas de avaliação de cada modelo

# %% [markdown]
# ### Avaliação Visual do Erro e Heterocedasticidade
#
# Homocedasticidade acontece quando os dados regredidos encontram-se mais homogeneamente e menos dispersos (concentrados) em torno da reta de regressão do modelo
#
# Heterocedasticidade é o fenômeno estatístico que ocorre quando o modelo de hipótese matemático apresenta variâncias para Y e X(X1, X2, X3,..., Xn) não iguais para todas as observações
#
# <img src='img/heterocedasticidade.jpg' width='65%'>

# %% [markdown]
# ### Exibindo comparativo das predições geradas por cada um dos modelos

# %% [markdown]
# ## <font color="#1D334A" size=8>Aula 05 - Machine Learning</font>

# %% [markdown]
# ## Criando um modelo de Regressão Linear com scikit-learn

# %% [markdown]
# ### Preparando dados de treinamento e de teste

# %% [markdown]
# ### Criando o modelo e gerando as métricas de avaliacao

# %% [markdown]
# ### Criando um Dummy Regressor e Avaliando os Resultados

# %% [markdown]
# ### Criando um regressor baseado em SVM

# %% [markdown]
# ### Parametrizando as variáveis antes de aplica ao regressor baseado em SVM

# %% [markdown]
# ### Árvores de Decisão

# %% [markdown]
# ### Visualizando as regras de decisão de uma Árvore de Decisão

# %% [markdown]
# ### Observando como uma árvore de decisão realiza predições

# %% [markdown]
# ### Usando uma Random Forest para Predição

# %% [markdown]
# ## <font color="#1D334A" size=8>Aula 06 - Classificação</font>

# %% [markdown]
# ### Observando variáveis que podem predizer se uma redação será zerada

# %% [markdown]
# ### Inspecionando visualmente a relação das variáveis explicativas, com a variável dependente

# %% [markdown]
# ### Tratando as variáveis categóricas para One Hot Encoding

# %% [markdown]
# ### Aprendizado Supervisionado - Gerando dados de Teste

# %% [markdown]
# ### Avaliando a qualidade do classificador - Métricas de Avaliação

# %% [markdown]
# #### Acurácia

# %% [markdown]
# ### Matriz de Confusão

# %% [markdown]
# ### Usando up sampling - SMOTE

# %% [markdown]
# ### Matriz de Confusão do Baseline

# %% [markdown]
# ### Precisão, Revocação e Especificidade
#
# | Precisão é a probabilidade de que um aluno que tenha sua nota prevista como zero, realmente zere a nota
#
# | Revocação é a probabilidade de que um aluno que zere a nota tenha a sua nota prevista como zero
#
# | Especificidade é a probabilidade de que um aluno que seja previsto como não zere, realmente tenha a sua nota como não zero -- uso em situações mais específicas

# %% [markdown]
# ### Pontuação F-Score

# %% [markdown]
# ### Avaliando algoritmos de Classificação

# %% [markdown]
# ### Função de Treinamento e Avaliação

# %% [markdown]
# ### Testando algoritmos

# %% [markdown]
# ## <font color="#1D334A" size=8>Aula 07 - Avaliação de Modelos e Overfit</font>

# %% [markdown]
# ## Limites do hold out: reduzindo a aleatoriedade do modelo

# %% [markdown]
# ## Usando Cross Validation para estimar o erro médio de um modelo

# %% [markdown]
# ## Fazendo função de geração do ic 0.95 dos estimadores

# %% [markdown]
# ## Avaliando Overfit da Decision Tree

# %% [markdown]
# ## Usando GridSearch para ajustar hiperparâmetros do modelo

# %% [markdown]
# ## <font color="#1D334A" size=6>Desafios da Aula 01 (Conhecendo os Dados)</font>

# %% [markdown]
# ### Desafio 01.A - Proporção de Inscritos por Idade

# %% [markdown]
# Gerar um dataframe que contenha, além do número absoluto de inscritos por idade, o valor percentual de cada idade entre os inscritos

# %% [markdown]
# ### Desafio 01.B - Estados dos Inscritos com 13 anos

# %% [markdown]
# ### Desafio 01.C - Utilizar o seaborn / matplotlib para melhorar a exibição do histograma da idade dos inscritos

# %% [markdown]
# ### Desafio 01.D - Utilizar o seaborn / matplotlib para plotar os histogramas das idades dos treineiros

# %% [markdown]
# ### Desafio 01.E - Comparar as distribuições das provas em Inglês e Espanhol

# %% [markdown]
# ### Desafio 01.F - Importar o Pandas Profiling e fazer um relatório inicial sobre os dados de notas e do questionário sócio econômico

# %% [markdown]
# ## <font color="#1D334A" size=6>Desafios da Aula 02 (Análise Exploratória: Visualizando os dados)</font>

# %% [markdown]
# ### Desafio 02.A - Rodar avaliação de percentual por UF para população completa dos alunos de 13 e 14 anos e comparar com a amostra

# %% [markdown]
# ### Desafio 02.B - Rodar avaliação de percentual por UF para população dos alunos de 13 e 14 anos e comparar com a amostra

# %% [markdown]
# ### Desafio 02.C - Verificar se quem zerou a prova foi eliminado ou não estava presente

# %% [markdown]
# ### Desafio 02.D -  Verificar se quem é eliminado tira zero ou não terá registro de notas (NaN)

# %% [markdown]
# ### Desafio 02.E - Verificar a proporção dos treineiros por estrato

# %% [markdown]
# ### Desafio 02.F1 - Escrever função para gerar gráfico de barras horizontais combinado

# %% [markdown]
# ### Desafio 02.F2 - Usar função de gráfico de barras horizontais combinado, para avaliar percentual de treneiros por estrato social

# %% [markdown]
# ### Desafio 02.G - Fazer o Boxplot para o Q25

# %% [markdown]
# ## <font color="#1D334A" size=6>Desafios da Aula 03 (Distribuições e Correlações)</font>

# %% [markdown]
# ### Desafio 03.A - Plotar Médias, Modas e Medianas das notas de LC e NT para entender as assimetrias

# %% [markdown]
# ### Desafio 03.B -Melhorar a visualização da matriz de correlação e analisá-la mais detalhadamente

# %% [markdown]
# ### Desafio 03.C - Filtrar as notas pelo estado e comparar as correlações com a do sample

# %% [markdown]
# ### Desafio 03.D - Avaliar a correlação entre Matemática e Linguagens

# %% [markdown]
# ###### A correlação entre MT e LC é a mais baixa dentre as correlações entre notas. Dela somente podemos extrair que existe uma tendência de alunos mais preparados, serem mais preparados nas diversas áreas de conhecimento. Talvez, a correlação seja melhor explicada pela correlação entre as notas e os extratos sociais

# %% [markdown]
# ## <font color="#1D334A" size=6>Desafios da Aula 04 (Regressão Linear e Inferência)</font>

# %% [markdown]
# ### Desafio 04.A - Gerar Modelo de Regressão para a variavel dependente (Nota de Matemática), à partir das variáveis padronizadas (z-score)
#
# <img src='img/padronizada.png' width='15%'>

# %% [markdown]
# ### Padronizando dados de treino e gerando dados de avaliação da predição do modelo normalizado

# %% [markdown]
# ### Função de Padronização

# %% [markdown]
# ### Avaliando dados gerados após padronização

# %% [markdown]
# ### Exibindo comparativo das métricas

# %% [markdown]
# ### Exibindo comparativo das predições

# %% [markdown]
# ## <font color="#1D334A" size=6>Desafios da Aula 05 (Machine Learning)</font>

# %% [markdown]
# ### Desafio 05.A - Avaliar visualmente a heterocedasticidade do melhor modelo dentre os gerados em aula

# %% [markdown]
# ### Desafio 05.B - Pesquisar outro modelo de ML e comparar com os demais preditores.

# %% [markdown]
# ## Desafio XVII - Ler a documentação do Dummy e alterar o método de regressão

# %% [markdown]
# ## Desafio XVIII - Buscar outras métricas para avaliar modelos de regressão

# %% [markdown]
# ## <font color="#1D334A" size=6>Desafios da Aula 07 (Validação de Modelos)</font>

# %% [markdown]
# ## Desafio XIX - Plotar gráfico de linhas com test_score e train_score (gráfico de aprendizagem)
